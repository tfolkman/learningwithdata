# %%
import requests
from bs4 import BeautifulSoup
import pickle

# %%
directory = "http://www.pro-football-reference.com/years/2015/draft.htm"
text = requests.get(directory).text

# %%
text
# Out:
# u'<!DOCTYPE html><html data-version="the-magglio-475" itemscope itemtype="http://schema.org/website" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/" lang="en"><head><title>2015 NFL Draft Listing | Pro-Football-Reference.com</title><link rel="dns-prefetch" href="http://d2ft4b0ve1aur1.cloudfront.net" /><link rel="dns-prefetch" href="http://m.pfref.com" />\n<link rel=subresource href="http://d2ft4b0ve1aur1.cloudfront.net/js-475/sr-pfr-min.js.jgz" /><script type="text/javascript">var sr_gzipEnabled = false; var sr_js_loader = new Array();</script><script type="text/javascript" src="http://d2ft4b0ve1aur1.cloudfront.net/js-100/sr.gzipcheck.js.jgz"></script><noscript><link type="text/css" rel="stylesheet" href="http://d2ft4b0ve1aur1.cloudfront.net/css-475/sr-pfr-min.css"></noscript><script type="text/javascript">\n(function () {var sr_css_file = \'http://d2ft4b0ve1aur1.cloudfront.net/css-475/sr-pfr-min.css\';if (sr_gzipEnabled) {sr_css_file = \'http://d2ft4b0ve1aur1.cloudfront.net/css-475/sr-pfr-min-gz.css\';}var head = document.getElementsByTagName("head")[0];if (head) {var scriptStyles = document.createElement("link");scriptStyles.rel = "stylesheet";scriptStyles.type = "text/css";scriptStyles.href = sr_css_file;head.appendChild(scriptStyles);}}());</script><!-- tiles, touch, favicons --><link rel="apple-touch-icon-precomposed" sizes="152x152" href="http://d2ft4b0ve1aur1.cloudfront.net/images-475/apple-touch-icon-152x152-pfr-precomposed.png"><link rel="apple-touch-icon-precomposed" sizes="144x144" href="http://d2ft4b0ve1aur1.cloudfront.net/images-475/apple-touch-icon-144x144-pfr-precomposed.png"><link rel="apple-touch-icon-precomposed" sizes="120x120" href="http://d2ft4b0ve1aur1.cloudfront.net/images-475/apple-touch-icon-120x120-pfr-precomposed.png"><link rel="apple-touch-icon-precomposed" sizes="114x114" href="http://d2ft4b0ve1aur1.cloudfront.net/images-475/apple-touch-icon-114x114-pfr-precomposed.png"><link rel="apple-touch-icon-precomposed" sizes="76x76" href="http://d2ft4b0ve1aur1.cloudfront.net/images-475/apple-touch-icon-76x76-pfr-precomposed.png"><link rel="apple-touch-icon-precomposed" sizes="72x72" href="http://d2ft4b0ve1aur1.cloudfront.net/images-475/apple-touch-icon-72x72-pfr-precomposed.png"><link rel="apple-touch-icon-precomposed" href="http://d2ft4b0ve1aur1.cloudfront.net/images-475/apple-touch-icon-pfr-precomposed.png"><link rel=icon href="http://d2ft4b0ve1aur1.cloudfront.net/images-475/favicon_pfr.png"><!--[if IE]><link rel="shortcut icon" href="http://d2ft4b0ve1aur1.cloudfront.net/images-475/favicon_pfr.ico"><![endif]--><meta name="msapplication-TileColor" content="#ffffff"/><meta name="msapplication-TileImage" content="http://d2ft4b0ve1aur1.cloudfront.net/images-475/ms-tile-144-pfr.png" /><link rel=search        type="application/opensearchdescription+xml" href="http://d2ft4b0ve1aur1.cloudfront.net/os-475/opensearch-pfr.xml" title="B-Ref Search"><!--[if lte IE 7 ]><style type="text/css">\n.uni_holder { display: none; }\n</style><![endif]--><!--[if lte IE 6]><style type="text/css">\n.hovermenu,.hovermenu_ajax,.sub_index,#quick_index {display:none!important}\n</style><![endif]-->\n<!--  ASYNCHRONOUS:googletag --><script type=\'text/javascript\'>\nvar googletag = googletag || {};googletag.cmd = googletag.cmd || [];(function() {var gads = document.createElement(\'script\');gads.async = true;gads.type = \'text/javascript\';var useSSL = \'https:\' == document.location.protocol;gads.src = (useSSL ? \'https:\' : \'http:\') + \'//www.googletagservices.com/tag/js/gpt.js\';var node = document.getElementsByTagName(\'script\')[0];node.parentNode.insertBefore(gads, node);})();</script><meta name=keywords content=""><meta property="fb:admins"     content="34208645"><meta property="fb:page_id"    content="10635217218"><meta property="og:site_name"  content="Pro-Football-Reference.com"><meta property="og:image"      content="http://d2ft4b0ve1aur1.cloudfront.net/images-434/apple-touch-ico ...

# %%
soup = BeautifulSoup(text)

# %%
trs = soup.findAll('tr')

# %%
column_headers = trs[1]
column_headers
# Out:
# <tr class="">
# <th align="center" class="tooltip sort_default_asc show_partial_when_sorting" data-stat="draft_round" tip="&lt;b&gt;Round selected in Draft&lt;/b&gt;">Rnd</th>
# <th align="center" class="tooltip sort_default_asc show_partial_when_sorting" data-stat="draft_pick" tip="&lt;b&gt;Overall Selection in Draft&lt;/b&gt;">Pick</th>
# <th align="left" class="tooltip sort_default_asc show_partial_when_sorting" data-stat="team">Tm</th>
# <th align="left" class="tooltip sort_default_asc show_partial_when_sorting" data-stat="player"></th>
# <th align="left" class="tooltip sort_default_asc" data-stat="pos" tip="&lt;b&gt;Position&lt;/b&gt;&lt;br&gt;In player and team season stats,&lt;br&gt;Capitals indicates primary starter.&lt;br&gt;Lower-case means part-time starter.">Pos</th>
# <th align="center" class="tooltip sort_default_asc" data-stat="age" tip=" Age as of September 1 of the draft year ">Age</th>
# <th align="center" class="tooltip sort_default_asc" data-stat="year_max" tip="Last Year">To</th>
# <th align="center" class="tooltip show_partial_when_sorting" data-stat="all_pros_first_team" tip="&lt;b&gt;First-team all-pro selections&lt;/b&gt;">AP1</th>
# <th align="center" class="tooltip show_partial_when_sorting" data-stat="pro_bowls" tip="&lt;b&gt;Pro Bowl Selections&lt;/b&gt;">PB</th>
# <th align="center" class="tooltip show_partial_when_sorting" data-stat="years_as_primary_starter" tip="Number of years as primary starter for his team at his position">St</th>
# <th align="center" class="tooltip show_partial_when_sorting" data-filter="1" data-name="Approximate Value (Weighted)" data-stat="career_av" tip="&lt;b&gt;Weighted Career Approximate Value&lt;/b&gt;.&lt;br&gt;See the glossary for details on how we compute Approximate Value.&lt;br&gt;The career AV is computed by summing &lt;br&gt;100 percent of the AV of his best season,&lt;br&gt;95 percent of the AV of his next-best season,&lt;br&gt;90 percent of the AV of his third-best season,&lt;br&gt;and so on">CarAV</th>
# <th align="CENTER" class="tooltip" data-stat="draft_av" tip="AV accumulated for team that drafted this player">DrAV</th>
# <th align="center" class="tooltip" data-filter="1" data-name="Games" data-stat="g" tip="Games played">G</th>
# <th align="center" class="tooltip" data-filter="1" data-name="Passes Completed" data-stat="pass_cmp" tip="Passes completed">Cmp</th>
# <th align="center" class="tooltip" data-filter="1" data-name="Pass Attempts" data-stat="pass_att" tip="Passes attempted">Att</th>
# <th align="center" class="tooltip" data-filter="1" data-name="Passing Yds" data-stat="pass_yds" tip="Yards Gained by Passing&lt;br&gt;For teams, sack yardage is deducted from this total">Yds</th>
# <th align="center" class="tooltip" data-filter="1" data-name="Passing TD" data-stat="pass_td" tip="Passing Touchdowns">TD</th>
# <th align="center" class="tooltip" data-filter="1" data-name="Passes Intercepted" data-stat="pass_int" tip="Interceptions thrown">Int</th>
# <th align="center" class="tooltip" data-filter="1" data-name="Rushing Att" data-stat="rush_att" tip="Rushing Attempts (sacks not included in NFL)">Att</th>
# <th align="center" class="tooltip" data-filter="1" data-name="Rushing Yds" data-stat="rush_yds" tip="Rushing Yards Gained (sack yardage is not included by NFL)">Yds</th>
# <th align="center" class="tooltip" data-filter="1" data-name="Rushing TD" data-stat="rush_td" tip="Rushing Touchdowns">TD</th>
# <th align="center" class="tooltip" data-filter="1" data-name="Receptions" data-stat="rec" tip="Receptions">Rec</th>
# <th align="center" class="tooltip" data-filter="1" data-name="Receiving Yds" data-stat="rec_yds" tip="Receiving Yards">Yds</th>
# <th align="center" class="tooltip" data-filter="1" data-name="Receiving TD" data-stat="rec_td" tip="Receiving Touchdowns">TD</th>
# <th align="center" class="tooltip" data-filter="1" data-name="Tackles" data-stat="tackles_solo" tip="Tackles&lt;br&gt;Before 1994:  unofficial and inconsistently recorded from team to team.  For amusement only.&lt;br&gt;1994-now:  unofficial but consistently recorded.&lt;br&gt;">Tkl</th>
# <th align="center" class="tooltip" data-filter="1" data-name="Interceptions" data-stat="def_int" tip="Passes intercepted on defense">Int</th>
# <th align="center" class="tooltip" data-filter="1" data-name="Sacks" data-stat="sacks" tip="Sacks">Sk</th>
# <th align="center" class="tooltip sort_default_asc" data-stat="college_id">College/Univ</th>
# <th align="CENTER" class="tooltip" data-stat="college_link"></th>
# </tr>

# %%
columns_ths = column_headers.findAll('th')
columns_ths
# Out:
# [<th align="center" class="tooltip sort_default_asc show_partial_when_sorting" data-stat="draft_round" tip="&lt;b&gt;Round selected in Draft&lt;/b&gt;">Rnd</th>,
#  <th align="center" class="tooltip sort_default_asc show_partial_when_sorting" data-stat="draft_pick" tip="&lt;b&gt;Overall Selection in Draft&lt;/b&gt;">Pick</th>,
#  <th align="left" class="tooltip sort_default_asc show_partial_when_sorting" data-stat="team">Tm</th>,
#  <th align="left" class="tooltip sort_default_asc show_partial_when_sorting" data-stat="player"></th>,
#  <th align="left" class="tooltip sort_default_asc" data-stat="pos" tip="&lt;b&gt;Position&lt;/b&gt;&lt;br&gt;In player and team season stats,&lt;br&gt;Capitals indicates primary starter.&lt;br&gt;Lower-case means part-time starter.">Pos</th>,
#  <th align="center" class="tooltip sort_default_asc" data-stat="age" tip=" Age as of September 1 of the draft year ">Age</th>,
#  <th align="center" class="tooltip sort_default_asc" data-stat="year_max" tip="Last Year">To</th>,
#  <th align="center" class="tooltip show_partial_when_sorting" data-stat="all_pros_first_team" tip="&lt;b&gt;First-team all-pro selections&lt;/b&gt;">AP1</th>,
#  <th align="center" class="tooltip show_partial_when_sorting" data-stat="pro_bowls" tip="&lt;b&gt;Pro Bowl Selections&lt;/b&gt;">PB</th>,
#  <th align="center" class="tooltip show_partial_when_sorting" data-stat="years_as_primary_starter" tip="Number of years as primary starter for his team at his position">St</th>,
#  <th align="center" class="tooltip show_partial_when_sorting" data-filter="1" data-name="Approximate Value (Weighted)" data-stat="career_av" tip="&lt;b&gt;Weighted Career Approximate Value&lt;/b&gt;.&lt;br&gt;See the glossary for details on how we compute Approximate Value.&lt;br&gt;The career AV is computed by summing &lt;br&gt;100 percent of the AV of his best season,&lt;br&gt;95 percent of the AV of his next-best season,&lt;br&gt;90 percent of the AV of his third-best season,&lt;br&gt;and so on">CarAV</th>,
#  <th align="CENTER" class="tooltip" data-stat="draft_av" tip="AV accumulated for team that drafted this player">DrAV</th>,
#  <th align="center" class="tooltip" data-filter="1" data-name="Games" data-stat="g" tip="Games played">G</th>,
#  <th align="center" class="tooltip" data-filter="1" data-name="Passes Completed" data-stat="pass_cmp" tip="Passes completed">Cmp</th>,
#  <th align="center" class="tooltip" data-filter="1" data-name="Pass Attempts" data-stat="pass_att" tip="Passes attempted">Att</th>,
#  <th align="center" class="tooltip" data-filter="1" data-name="Passing Yds" data-stat="pass_yds" tip="Yards Gained by Passing&lt;br&gt;For teams, sack yardage is deducted from this total">Yds</th>,
#  <th align="center" class="tooltip" data-filter="1" data-name="Passing TD" data-stat="pass_td" tip="Passing Touchdowns">TD</th>,
#  <th align="center" class="tooltip" data-filter="1" data-name="Passes Intercepted" data-stat="pass_int" tip="Interceptions thrown">Int</th>,
#  <th align="center" class="tooltip" data-filter="1" data-name="Rushing Att" data-stat="rush_att" tip="Rushing Attempts (sacks not included in NFL)">Att</th>,
#  <th align="center" class="tooltip" data-filter="1" data-name="Rushing Yds" data-stat="rush_yds" tip="Rushing Yards Gained (sack yardage is not included by NFL)">Yds</th>,
#  <th align="center" class="tooltip" data-filter="1" data-name="Rushing TD" data-stat="rush_td" tip="Rushing Touchdowns">TD</th>,
#  <th align="center" class="tooltip" data-filter="1" data-name="Receptions" data-stat="rec" tip="Receptions">Rec</th>,
#  <th align="center" class="tooltip" data-filter="1" data-name="Receiving Yds" data-stat="rec_yds" tip="Receiving Yards">Yds</th>,
#  <th align="center" class="tooltip" data-filter="1" data-name="Receiving TD" data-stat="rec_td" tip="Receiving Touchdowns">TD</th>,
#  <th align="center" class="tooltip" data-filter="1" data-name="Tackles" data-stat="tackles_solo" tip="Tackles&lt;br&gt;Before 1994:  unofficial and inconsistently recorded from team to team.  For amusement only.&lt;br&gt;1994-now:  unofficial but consistently recorded.&lt;br&gt;">Tkl</th>,
#  <th align="center" class="tooltip" data-filter="1" data-name="Interceptions" data-stat="def_int" tip="Passes intercepted on defense">Int</th>,
#  <th align="center" class="tooltip" data-filter="1" data-name="Sacks" data-stat="sacks" tip="Sacks">Sk</th>,
#  <th align="center" class="tooltip sort_default_asc" data-stat="college_id">College/Univ</th>,
#  <th align="CENTER" class="tooltip" data-stat="college_link"></th>]

# %%
column_names = [c.text for c in columns_ths]
column_names
# Out:
# [u'Rnd',
#  u'Pick',
#  u'Tm',
#  u'',
#  u'Pos',
#  u'Age',
#  u'To',
#  u'AP1',
#  u'PB',
#  u'St',
#  u'CarAV',
#  u'DrAV',
#  u'G',
#  u'Cmp',
#  u'Att',
#  u'Yds',
#  u'TD',
#  u'Int',
#  u'Att',
#  u'Yds',
#  u'TD',
#  u'Rec',
#  u'Yds',
#  u'TD',
#  u'Tkl',
#  u'Int',
#  u'Sk',
#  u'College/Univ',
#  u'']

# %%
first_row = trs[2].findAll('td')

# %%
first_row[0]
# Out:
# <td align="right">1</td>

# %%
first_row_values = [c.text for c in first_row]
first_row_values
# Out:
# [u'1',
#  u'1',
#  u'TAM',
#  u'Jameis Winston',
#  u'QB',
#  u'21',
#  u'2015',
#  u'0',
#  u'1',
#  u'1',
#  u'13',
#  u'13',
#  u'16',
#  u'312',
#  u'535',
#  u'4042',
#  u'22',
#  u'15',
#  u'53',
#  u'210',
#  u'6',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'Florida St.',
#  u'College Stats']

# %%
trs[-4]
# Out:
# <tr class="">
# <td align="right">7</td>
# <td align="right" csk="255.5">256</td>
# <td align="left" csk="crd07"><a href="/teams/crd/2015_draft.htm" title="Arizona Cardinals">ARI</a></td>
# <td align="left" csk="Christian, Gerald"><strong><a href="/players/C/ChriGe00.htm">Gerald Christian</a></strong></td>
# <td align="left" csk="TE--------0256">TE</td>
# <td align="right">24</td>
# <td align="right"></td>
# <td align="right">0</td>
# <td align="right">0</td>
# <td align="right">0</td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="right"></td>
# <td align="left"><a href="/schools/louisville/">Louisville</a></td>
# <td align=""><a href="http://www.sports-reference.com/cfb/players/gerald-christian-1.html">College Stats</a></td>
# </tr>

# %%
column_names[3] = u'Name'
column_names[-1] = u'College_Stats'
column_names
# Out:
# [u'Rnd',
#  u'Pick',
#  u'Tm',
#  u'Name',
#  u'Pos',
#  u'Age',
#  u'To',
#  u'AP1',
#  u'PB',
#  u'St',
#  u'CarAV',
#  u'DrAV',
#  u'G',
#  u'Cmp',
#  u'Att',
#  u'Yds',
#  u'TD',
#  u'Int',
#  u'Att',
#  u'Yds',
#  u'TD',
#  u'Rec',
#  u'Yds',
#  u'TD',
#  u'Tkl',
#  u'Int',
#  u'Sk',
#  u'College/Univ',
#  u'College_Stats']

# %%
player_data = []
player_data.append(column_names)
for tr in trs[2:-3]:
    player_data.append([c.text for c in tr.findAll('td')])

# %%
len(player_data)
# Out:
# 269

# %%
player_data[1]
# Out:
# [u'1',
#  u'1',
#  u'TAM',
#  u'Jameis Winston',
#  u'QB',
#  u'21',
#  u'2015',
#  u'0',
#  u'1',
#  u'1',
#  u'13',
#  u'13',
#  u'16',
#  u'312',
#  u'535',
#  u'4042',
#  u'22',
#  u'15',
#  u'53',
#  u'210',
#  u'6',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'Florida St.',
#  u'College Stats']

# %%
player_data[-1]
# Out:
# [u'7',
#  u'256',
#  u'ARI',
#  u'Gerald Christian',
#  u'TE',
#  u'24',
#  u'',
#  u'0',
#  u'0',
#  u'0',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'Louisville',
#  u'College Stats']

# %%
years = range(2000,2016)
player_data = []
new_columns = column_names
new_columns.append(u'year')
player_data.append(new_columns)
for year in years:
    directory = "http://www.pro-football-reference.com/years/{}/draft.htm".format(str(year))
    text = requests.get(directory).text
    soup = BeautifulSoup(text)
    trs = soup.findAll('tr')
    for tr in trs[2:-3]:
        data = [c.text for c in tr.findAll('td')]
        data.append(year)
        player_data.append(data)

# %%
len(player_data)
# Out:
# 4261

# %%
player_data[0]
# Out:
# [u'Rnd',
#  u'Pick',
#  u'Tm',
#  u'Name',
#  u'Pos',
#  u'Age',
#  u'To',
#  u'AP1',
#  u'PB',
#  u'St',
#  u'CarAV',
#  u'DrAV',
#  u'G',
#  u'Cmp',
#  u'Att',
#  u'Yds',
#  u'TD',
#  u'Int',
#  u'Att',
#  u'Yds',
#  u'TD',
#  u'Rec',
#  u'Yds',
#  u'TD',
#  u'Tkl',
#  u'Int',
#  u'Sk',
#  u'College/Univ',
#  u'College_Stats',
#  u'year']

# %%
player_data[1]
# Out:
# [u'1',
#  u'1',
#  u'CLE',
#  u'Courtney Brown',
#  u'DE',
#  u'22',
#  u'2005',
#  u'0',
#  u'0',
#  u'4',
#  u'28',
#  u'21',
#  u'61',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'155',
#  u'',
#  u'19.0',
#  u'Penn St.',
#  u'College Stats',
#  2000]

# %%
player_data[-1]
# Out:
# [u'7',
#  u'256',
#  u'ARI',
#  u'Gerald Christian',
#  u'TE',
#  u'24',
#  u'',
#  u'0',
#  u'0',
#  u'0',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'Louisville',
#  u'College Stats',
#  2015]

# %%
with open("../data/2015_draft", 'wb') as f:
    pickle.dump(player_data, f)
